# %%
# Lib untuk manipulasi data
import numpy as np
import pandas as pd

# lib untuk praproses dataset
from sklearn.preprocessing import MinMaxScaler

# %%
# load dataset
dataset = pd.read_csv("dataset/ekstrasi-fitur-kopra-nonTelungkup_v3.csv")
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1839 entries, 0 to 1838
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mean_R           1839 non-null   float64
#  1   Mean_G           1839 non-null   float64
#  2   Mean_B           1839 non-null   float64
#  3   Mean_H           1839 non-null   float64
#  4   Mean_V           1839 non-null   float64
#  5   Mean_S           1839 non-null   float64
#  6   Mean_Gray        1839 non-null   float64
#  7   Standar_Deviasi  1839 non-null   float64
#  8   Luas             1839 non-null   float64
#  9   Perimeter        1839 non-null   float64
#  10  Contrast         1839 non-null   float64
#  11  Dissimilarity    1839 non-null   float64
#  12  Homogeneity      1839 non-null   float64
#  13  Energy           1839 non-null   float64
#  14  Correlation      1839 non-null   float64
#  15  Class            1839 non-null   object
# dtypes: float64(15), object(1)
# memory usage: 230.0+ KB
# None

# %%
# Feature and Target
x = dataset.drop(columns=["Class"], axis=1)
y = dataset[["Class"]]

# Normalized
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(x)

# %%
# Results Normalized
x = pd.DataFrame(scaled, columns=x.columns)
y = pd.DataFrame(y, columns=y.columns)

# Finally dataset
dataset = pd.concat([x,y],axis=1)

# %%
dataset.tail()
# Out:
#         Mean_R    Mean_G    Mean_B    Mean_H    Mean_V    Mean_S  Mean_Gray  \
# 1834  0.336928  0.334134  0.271181  0.103884  0.337031  0.538993   0.329084
# 1835  0.244958  0.316936  0.277184  0.176806  0.259731  0.402622   0.290991
# 1836  0.257276  0.262330  0.163118  0.095408  0.257166  0.584961   0.251520
# 1837  0.345604  0.383910  0.301748  0.121680  0.345519  0.453127   0.364465
# 1838  0.272105  0.291334  0.176039  0.105840  0.272034  0.575734   0.274483
#
#       Standar_Deviasi      Luas  Perimeter  Contrast  Dissimilarity  \
# 1834         0.250636  0.001596   0.015660  0.110374       0.170833
# 1835         0.215594  0.002983   0.025407  0.214211       0.350142
# 1836         0.238112  0.000872   0.028550  0.177999       0.273175
# 1837         0.292107  0.001988   0.028253  0.151017       0.258955
# 1838         0.263064  0.000151   0.012406  0.113284       0.229726
#
#       Homogeneity    Energy  Correlation   Class
# 1834     0.406504  0.096605     0.793782  Reject
# 1835     0.168067  0.089078     0.591733  Reject
# 1836     0.356192  0.257116     0.683407  Reject
# 1837     0.352847  0.188386     0.779754  Reject
# 1838     0.411704  0.260647     0.801712  Reject
